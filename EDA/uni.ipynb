# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set()

# %% [markdown]
# ## EDA ##

# %% [markdown]
# * Elegi las 10 monedas con mayor capitalizacion de mercado.
# * La capitalizacion de mercado de una criptomoneda, es el valor total del conjunto de criptomonedas de la moneda en cuestion, que se han minado o están en circulación.
# * Se utiliza en muchas plataformas y exchanges como criterio para clasificar a las criptomonedas, y ya que en estre proyecto estamos iniciando a nuestro cliente en el ambito de las criptomonedas, me parecio un parametro mas confiable para tener como referencia a la hora de elegir 10 criptomonedas.

# %% [markdown]
# A su vez podemos clasificarlas en 3 tipos segun capitalizacion=
# * Criptomonedas de gran capitalización (más de 10.000 millones de dólares)
# * Criptomonedas de capitalización media (entre 1000 millones y 10 000 millones de dólares)
# * Criptomonedas de baja capitalización (menos de 1000 millones de dólares)
#
# Las monedas elegidas son todas de gran capitalizacion

# %% [markdown]
# ### Capitalizacion de mercado
# Número total de monedas en circulación * su precio en ese momento

# %% [markdown]
# * Me conecto a la API coingecko y creo distintos CSV con la informacion que considero mas relevante.
# * Para empezar el EDA primero me traigo el DF que cree que tiene las 10 monedas que elegi, y ademas tiene el id, el nombre, el ranking segun el market cap, el volumen total, el precio maximo en las ultimas 24 hs y el precio minimo en las ultimas 24 hs (como trae datos actuales la ultima vez que lo actualice fue el 21/08), cambio de precio en las ultimas 24 hs y porcentaje de cambio de precio, los valores historicos maximos y minimos y sus porcentajes y sus fechas.

# %%
top10= pd.read_csv(r'C:\Users\flori\Desktop\DATA SCIENCE\LABS\Trabajos\tp2\Proyecto2_Data_Analytics\ETL\10cripto.csv')

# %%
top10
# Out:
#              id               name  current_price    market_cap  \
# 0       bitcoin            Bitcoin   25934.000000  505170783253
# 1      ethereum           Ethereum    1643.740000  197714649390
# 2        tether             Tether       1.001000   82844515691
# 3   binancecoin                BNB     214.770000   33088471047
# 4        ripple                XRP       0.518919   27462950643
# 5      usd-coin           USD Coin       1.000000   25908990808
# 6  staked-ether  Lido Staked Ether    1644.080000   13707984807
# 7       cardano            Cardano       0.260013    9119958348
# 8      dogecoin           Dogecoin       0.063289    8923960066
# 9        solana             Solana      20.610000    8424042500
#
#    market_cap_rank  total_volume      high_24h       low_24h  \
# 0                1   12543220744  26183.000000  25575.000000
# 1                2   10421599453   1666.290000   1597.410000
# 2                3   14974278845      1.004000      0.996619
# 3                4     819517650    216.380000    204.210000
# 4                5    1087987220      0.522798      0.507130
# 5                6    5571671979      1.005000      0.997146
# 6                7      53210243   1667.910000   1601.730000
# 7                8     197614620      0.261076      0.250525
# 8                9     381482875      0.064087      0.060500
# 9               10     468560257     21.050000     19.660000
#
#    price_change_24h  price_change_percentage_24h  market_cap_change_24h  \
# 0       -122.311207                     -0.46942          -1.874780e+09
# 1        -20.469917                     -1.23001          -2.144793e+09
# 2          0.001903                      0.19043           5.031071e+07
# 3          5.620000                      2.68699           9.025285e+08
# 4          0.000106                      0.02043           6.952652e+07
# 5          0.000282                      0.02817          -3.706807e+07
# 6        -20.800637                     -1.24938          -9.496924e+07
# 7          0.000246                      0.09452           2.645265e+07
# 8          0.000255                      0.40438           5.884730e+07
# 9         -0.373236                     -1.77833          -1.301006e+08
#
#    market_cap_change_percentage_24h           ath  ath_change_percentage  \
# 0                          -0.36975  69045.000000              -62.41306
# 1                          -1.07315   4878.260000              -66.28483
# 2                           0.06077      1.320000              -24.42770
# 3                           2.80411    686.310000              -68.66399
# 4                           0.25381      3.400000              -84.70593
# 5                          -0.14287      1.170000              -14.73916
# 6                          -0.68804   4829.570000              -65.95673
# 7                           0.29090      3.090000              -91.56971
# 8                           0.66381      0.731578              -91.33084
# 9                          -1.52091    259.960000              -92.06000
#
#                    ath_date         atl  atl_change_percentage  \
# 0  2021-11-10T14:24:11.849Z   67.810000            38171.93830
# 1  2021-11-10T14:24:19.604Z    0.432979           379760.08334
# 2  2018-07-24T00:00:00.000Z    0.572521               74.64750
# 3  2021-05-10T07:24:17.097Z    0.039818           540014.32955
# 4  2018-01-07T00:00:00.000Z    0.002686            19249.27011
# 5  2019-05-08T00:40:28.300Z    0.877647               13.92503
# 6  2021-11-10T14:40:47.256Z  482.900000              240.47558
# 7  2021-09-02T06:00:10.474Z    0.019253             1251.67982
# 8  2021-05-08T05:08:23.458Z    0.000087            72879.21861
# 9  2021-11-06T21:54:35.825Z    0.500801             4021.54820
#
#                    atl_date
# 0  2013-07-06T00:00:00.000Z
# 1  2015-10-20T00:00:00.000Z
# 2  2015-03-02T00:00:00.000Z
# 3  2017-10-19T00:00:00.000Z
# 4  2014-05-22T00:00:00.000Z
# 5  2023-03-11T08:02:13.981Z
# 6  2020-12-22T04:08:21.854Z
# 7  2020-03-13T02:22:55.044Z
# 8  2015-05-06T00:00:00.000Z
# 9  2020-05-11T19:35:23.449Z

# %%
#Miro el tipo de dato 
top10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                10 non-null     object
#  1   name                              10 non-null     object
#  2   current_price                     10 non-null     float64
#  3   market_cap                        10 non-null     int64
#  4   market_cap_rank                   10 non-null     int64
#  5   total_volume                      10 non-null     int64
#  6   high_24h                          10 non-null     float64
#  7   low_24h                           10 non-null     float64
#  8   price_change_24h                  10 non-null     float64
#  9   price_change_percentage_24h       10 non-null     float64
#  10  market_cap_change_24h             10 non-null     float64
#  11  market_cap_change_percentage_24h  10 non-null     float64
#  12  ath                               10 non-null     float64
#  13  ath_change_percentage             10 non-null     float64
#  14  ath_date                          10 non-null     object
#  15  atl                               10 non-null     float64
#  16  atl_change_percentage             10 non-null     float64
#  17  atl_date                          10 non-null     object
# dtypes: float64(11), int64(3), object(4)
# memory usage: 1.5+ KB

# %%
#transformo la fecha en datetime porque esta en str
top10['ath_date']= pd.to_datetime(top10['ath_date'])
top10['atl_date']=pd.to_datetime(top10['atl_date'])

# %%
# Con la funcion describe miro los valores mas relavantes, resumen de estadistica de cada columna
top10.describe()
# Out:
#        current_price    market_cap  market_cap_rank  total_volume  \
# count      10.000000  1.000000e+01         10.00000  1.000000e+01
# mean     2946.004322  9.123663e+10          5.50000  4.651914e+09
# std      8105.103844  1.566499e+11          3.02765  5.841175e+09
# min         0.063289  8.424042e+09          1.00000  5.321024e+07
# 25%         0.639189  1.026696e+10          3.25000  4.032522e+08
# 50%        10.805500  2.668597e+10          5.50000  9.537524e+08
# 75%      1286.497500  7.040550e+10          7.75000  9.209118e+09
# max     25934.000000  5.051708e+11         10.00000  1.497428e+10
#
#            high_24h       low_24h  price_change_24h  \
# count     10.000000     10.000000         10.000000
# mean    2975.748696   2900.082192        -15.833221
# std     8182.667304   7993.992231         38.494632
# min        0.064087      0.060500       -122.311207
# 25%        0.643099      0.629502        -15.445747
# 50%       11.027500     10.328573          0.000176
# 75%     1303.812500   1249.110000          0.000275
# max    26183.000000  25575.000000          5.620000
#
#        price_change_percentage_24h  market_cap_change_24h  \
# count                    10.000000           1.000000e+01
# mean                     -0.130222          -3.174044e+08
# std                       1.234547           9.405012e+08
# min                      -1.778330          -2.144793e+09
# 25%                      -1.039862          -1.213178e+08
# 50%                       0.024300          -5.307710e+06
# 75%                       0.166453           5.671315e+07
# max                       2.686990           9.025285e+08
#
#        market_cap_change_percentage_24h           ath  ath_change_percentage  \
# count                         10.000000     10.000000              10.000000
# mean                           0.027868   7970.881158             -66.215195
# std                            1.180583  21549.744399              27.284529
# min                           -1.520910      0.731578             -92.060000
# 25%                           -0.608467      1.762500             -89.674612
# 50%                           -0.041050    131.680000             -67.474410
# 75%                            0.281627   3793.755000             -63.298977
# max                            2.804110  69045.000000             -14.739160
#
#               atl  atl_change_percentage
# count   10.000000              10.000000
# mean    55.315579          105567.711604
# std    151.728563          191933.030743
# min      0.000087              13.925030
# 25%      0.024394             493.276640
# 50%      0.466890           11635.409155
# 75%      0.801365           64202.398532
# max    482.900000          540014.329550

# %% [markdown]
# De las 10 criptomonedas con mayor market_cap, puedo ver un promedio de precio de las mismas de 2900 usd, pero teniendo en cuenta la variacion de un valor minimo de 0.06 a 25934, es decir entre la que mas precio tiene actualmente y la que menos tiene una gran diferencia.

# %%
#Grafico las monedas y la capitalizacion de mercado
plt.figure(figsize=(10, 6))
plt.barh( top10['name'],top10['market_cap'], color='blue')
plt.xlabel('USD')
plt.ylabel('Criptomoneda')
plt.title('Capitalizacion de mercado')
plt.show()

# %%
# Creo un scatterplot 
plt.figure(figsize=(5,5))
sns.scatterplot(data=top10, x='current_price',y='name', color='red')

# Personalizar el gráfico
plt.title('')
plt.xlabel('')
plt.ylabel('')

# Mostrar el gráfico
plt.show()

# %%
sns.displot(top10['current_price'], bins=20, rug = True)

# %% [markdown]
# Con estos dos ultimos graficos podemos ver al diferencia entre el precio de bitcoin y del resto de las monedas, es bastante la diferencia, a pesar de que comparten el ranking de las 10 monedas con mas capitalizacion del mercado.

# %%
top10bit=top10[top10['name']=='Bitcoin']

plt.figure(figsize=(6, 3))
plt.plot(top10bit['ath_date'], top10bit['ath'], label='Máximo Histórico', marker='o')
plt.plot(top10bit['atl_date'], top10bit['atl'], label='Mínimo Histórico', marker='o')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.title('Precio Histórico Máximo y Mínimo Bitcoin')
plt.legend()
plt.grid(True)
plt.show()

# %%
top10['name'].tolist()
# Out:
# ['Bitcoin',
#  'Ethereum',
#  'Tether',
#  'BNB',
#  'XRP',
#  'USD Coin',
#  'Lido Staked Ether',
#  'Cardano',
#  'Dogecoin',
#  'Solana']

# %%
colores_criptos = {
    'Bitcoin': 'blue',
    'Ethereum': 'green',
    'XRP': 'red',
    'Tether':'pink',
    'BNB':'yellow',
    'USD Coin': 'black',
    'Lido Staked Ether':'orange',
    'Cardano': 'brown',
    'Dogecoin':'purple',
    'Solana':'grey'
    # Agrega más criptomonedas y colores según sea necesario
}

plt.figure(figsize=(12, 6))

# Para cada criptomoneda, graficar el precio máximo histórico
for cripto, color in colores_criptos.items():
    data = top10[top10['name'] == cripto]
    plt.scatter(data['ath_date'], data['ath'], label=f'Máx. {cripto}', color=color, marker='o')

# Para cada criptomoneda, graficar el precio mínimo histórico
for cripto, color in colores_criptos.items():
    data = top10[top10['name'] == cripto]
    plt.scatter(data['atl_date'], data['atl'], label=f'Mín. {cripto}', color=color, marker='x')

plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.title('Máximo y Mínimo Histórico de Criptomonedas')
plt.legend(fontsize='small')
plt.grid(True)
plt.show()
